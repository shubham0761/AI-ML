# %% [markdown]
# # <p style="background-color:coral;font-family:newtimeroman;font-size:150%;color:white;text-align:center;border-radius:20px 60px;">Covid_19_india EDA & Data Visualization</p>

# %% [markdown]
# !pip install seaborn

# %% [markdown]
# Link for Data set: https://www.kaggle.com/datasets/naindeepkaur/covid-19-india

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# # Use the appropriate engine to read the Excel file
# covid_df = pd.read_excel("covid_19_india.xls", engine="xlrd")  # If the file is .xls
# ### OR
# covid_df = pd.read_excel("covid_19_india.xlsx", engine="openpyxl")  # If the file is .xlsx

# %% [markdown]
# # <p style="background-color:coral;font-family:newtimeroman;font-size:150%;color:white;text-align:center;border-radius:20px 60px;">Loading the dataset</p>

# %%
covid_df=pd.read_csv("covid_19_india - covid_19_india.csv")

# %%
covid_df.to_string()
# Out:
# '         Sno        Date   Time                      State/UnionTerritory ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  Confirmed\n0          1  2020-01-30  18:00                                    Kerala                       1                        0        0       0          1\n1          2  2020-01-31  18:00                                    Kerala                       1                        0        0       0          1\n2          3  2020-02-01  18:00                                    Kerala                       2                        0        0       0          2\n3          4  2020-02-02  18:00                                    Kerala                       3                        0        0       0          3\n4          5  2020-02-03  18:00                                    Kerala                       3                        0        0       0          3\n5          6  2020-02-04  18:00                                    Kerala            
# ...

# %% [markdown]
# # <p style="background-color:coral;font-family:newtimeroman;font-size:150%;color:white;text-align:center;border-radius:20px 60px;">Understanding the dataset</p>

# %%
covid_df.shape
# Out:
# (18110, 9)

# %%
covid_df.head(20)
# Out:
#     Sno        Date   Time State/UnionTerritory ConfirmedIndianNational  \
# 0     1  2020-01-30  18:00               Kerala                       1
# 1     2  2020-01-31  18:00               Kerala                       1
# 2     3  2020-02-01  18:00               Kerala                       2
# 3     4  2020-02-02  18:00               Kerala                       3
# 4     5  2020-02-03  18:00               Kerala                       3
# 5     6  2020-02-04  18:00               Kerala                       3
# 6     7  2020-02-05  18:00               Kerala                       3
# 7     8  2020-02-06  18:00               Kerala                       3
# 8     9  2020-02-07  18:00               Kerala                       3
# 9    10  2020-02-08  18:00               Kerala                       3
# 10   11  2020-02-09  18:00               Kerala                       3
# 11   12  2020-02-10  18:00               Kerala                       3
# ...

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18110 entries, 0 to 18109
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       18110 non-null  int64
#  1   Date                      18110 non-null  object
#  2   Time                      18110 non-null  object
#  3   State/UnionTerritory      18110 non-null  object
#  4   ConfirmedIndianNational   18110 non-null  object
#  5   ConfirmedForeignNational  18110 non-null  object
#  6   Cured                     18110 non-null  int64
#  7   Deaths                    18110 non-null  int64
#  8   Confirmed                 18110 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 1.2+ MB

# %%
covid_df.describe()
# Out:
#                 Sno         Cured         Deaths     Confirmed
# count  18110.000000  1.811000e+04   18110.000000  1.811000e+04
# mean    9055.500000  2.786375e+05    4052.402264  3.010314e+05
# std     5228.051023  6.148909e+05   10919.076411  6.561489e+05
# min        1.000000  0.000000e+00       0.000000  0.000000e+00
# 25%     4528.250000  3.360250e+03      32.000000  4.376750e+03
# 50%     9055.500000  3.336400e+04     588.000000  3.977350e+04
# 75%    13582.750000  2.788698e+05    3643.750000  3.001498e+05
# max    18110.000000  6.159676e+06  134201.000000  6.363442e+06

# %%
vaccine_df=pd.read_csv("covid_vaccine_statewise - covid_vaccine_statewise.csv")

# %%
vaccine_df.head(10)
# Out:
#    Updated On  State  Total Doses Administered  Sessions    Sites  \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
# 5  21/01/2021  India                  365965.0   32226.0  12600.0
# 6  22/01/2021  India                  549381.0   36988.0  14115.0
# 7  23/01/2021  India                  759008.0   43076.0  15605.0
# 8  24/01/2021  India                  835058.0   49851.0  18111.0
# 9  25/01/2021  India                 1277104.0   55151.0  19682.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# ...

# %%
vaccine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7845 entries, 0 to 7844
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Updated On                           7845 non-null   object
#  1   State                                7845 non-null   object
#  2   Total Doses Administered             7621 non-null   float64
#  3   Sessions                             7621 non-null   float64
#  4   Sites                                7621 non-null   float64
#  5   First Dose Administered              7621 non-null   float64
#  6   Second Dose Administered             7621 non-null   float64
#  7   Male (Doses Administered)            7461 non-null   float64
#  8   Female (Doses Administered)          7461 non-null   float64
#  9   Transgender (Doses Administered)     7461 non-null   float64
#  10  Covaxin (Doses Administered)         7621 non-null   float64
# ...

# %%
vaccine_df.describe()
# Out:
#        Total Doses Administered      Sessions         Sites  \
# count              7.621000e+03  7.621000e+03   7621.000000
# mean               9.188171e+06  4.792358e+05   2282.872064
# std                3.746180e+07  1.911511e+06   7275.973730
# min                7.000000e+00  0.000000e+00      0.000000
# 25%                1.356570e+05  6.004000e+03     69.000000
# 50%                8.182020e+05  4.547000e+04    597.000000
# 75%                6.625243e+06  3.428690e+05   1708.000000
# max                5.132284e+08  3.501031e+07  73933.000000
#
#        First Dose Administered  Second Dose Administered  \
# count             7.621000e+03              7.621000e+03
# mean              7.414415e+06              1.773755e+06
# std               2.995209e+07              7.570382e+06
# min               7.000000e+00              0.000000e+00
# 25%               1.166320e+05              1.283100e+04
# 50%               6.614590e+05              1.388180e+05
# ...

# %% [markdown]
# # <p style="background-color:coral;font-family:newtimeroman;font-size:150%;color:white;text-align:center;border-radius:20px 60px;">Handling missing data</p>

# %%
covid_df.drop(["Sno","Time","ConfirmedIndianNational","ConfirmedForeignNational"],inplace=True,axis=1)

# %%
covid_df.head()
# Out:
#          Date State/UnionTerritory  Cured  Deaths  Confirmed
# 0  2020-01-30               Kerala      0       0          1
# 1  2020-01-31               Kerala      0       0          1
# 2  2020-02-01               Kerala      0       0          2
# 3  2020-02-02               Kerala      0       0          3
# 4  2020-02-03               Kerala      0       0          3

# %%
covid_df['Date']=pd.to_datetime(covid_df['Date'],format='%Y-%m-%d')

# %%
covid_df.head()
# Out:
#         Date State/UnionTerritory  Cured  Deaths  Confirmed
# 0 2020-01-30               Kerala      0       0          1
# 1 2020-01-31               Kerala      0       0          1
# 2 2020-02-01               Kerala      0       0          2
# 3 2020-02-02               Kerala      0       0          3
# 4 2020-02-03               Kerala      0       0          3

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18110 entries, 0 to 18109
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  18110 non-null  datetime64[ns]
#  1   State/UnionTerritory  18110 non-null  object
#  2   Cured                 18110 non-null  int64
#  3   Deaths                18110 non-null  int64
#  4   Confirmed             18110 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 707.5+ KB

# %% [markdown]
# # <p style="background-color:coral;font-family:newtimeroman;font-size:150%;color:white;text-align:center;border-radius:20px 60px;">Data preprocessing</p>

# %%
#Active cases
covid_df['Active_cases']=covid_df['Confirmed']-(covid_df['Cured']+covid_df['Deaths'])
covid_df.tail()
# Out:
#             Date State/UnionTerritory    Cured  Deaths  Confirmed  \
# 18105 2021-08-11            Telangana   638410    3831     650353
# 18106 2021-08-11              Tripura    77811     773      80660
# 18107 2021-08-11          Uttarakhand   334650    7368     342462
# 18108 2021-08-11        Uttar Pradesh  1685492   22775    1708812
# 18109 2021-08-11          West Bengal  1506532   18252    1534999
#
#        Active_cases
# 18105          8112
# 18106          2076
# 18107           444
# 18108           545
# 18109         10215

# %%
covid_df['State/UnionTerritory']=covid_df['State/UnionTerritory'].replace('Maharashtra***',"Maharashtra")
covid_df['State/UnionTerritory']=covid_df['State/UnionTerritory'].replace('Bihar****',"Bihar")
covid_df['State/UnionTerritory']=covid_df['State/UnionTerritory'].replace('Madhya Pradesh***',"Madhya Pradesh")
covid_df['State/UnionTerritory']=covid_df['State/UnionTerritory'].replace('Karanataka',"Karnataka")

# %%
#pivot table
statewise_data=pd.pivot_table(covid_df, values=['Confirmed','Deaths','Cured'],index="State/UnionTerritory", aggfunc='max')

# %%
print(statewise_data)
# Out:
#                                           Confirmed    Cured  Deaths
# State/UnionTerritory
# Andaman and Nicobar Islands                    7548     7412     129
# Andhra Pradesh                              1985182  1952736   13564
# Arunachal Pradesh                             50605    47821     248
# Assam                                        576149   559684    5420
# Bihar                                        725279   715352    9646
# Bihar****                                    715730   701234    9452
# Cases being reassigned to states               9265        0       0
# Chandigarh                                    61992    61150     811
# Chhattisgarh                                1003356   988189   13544
# Dadra and Nagar Haveli                        10377    10261       4
# Dadra and Nagar Haveli and Daman and Diu      10654    10646       4
# Daman & Diu                                       2        0       0
# ...

# %%
statewise_data['Recovery Rate']=statewise_data['Cured']*100/statewise_data['Confirmed']

# %%
statewise_data['Mortality Rate']=statewise_data['Deaths']*100/statewise_data['Confirmed']

# %%
statewise_data=statewise_data.sort_values(by="Confirmed",ascending=False)

# %% [markdown]
# # <p style="background-color:coral;font-family:newtimeroman;font-size:150%;color:white;text-align:center;border-radius:20px 60px;">Data visualization</p>

# %%
statewise_data.style.background_gradient(cmap="CMRmap")
# Out:
# <style type="text/css">
# #T_39b8f_row0_col0, #T_39b8f_row0_col1, #T_39b8f_row0_col2, #T_39b8f_row16_col4, #T_39b8f_row35_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_39b8f_row0_col3, #T_39b8f_row27_col3 {
#   background-color: #f9f9df;
#   color: #000000;
# }
# #T_39b8f_row0_col4 {
#   background-color: #e6c72f;
#   color: #000000;
# }
# #T_39b8f_row1_col0 {
#   background-color: #f26112;
#   color: #f1f1f1;
# }
# #T_39b8f_row1_col1 {
#   background-color: #f45b16;
#   color: #f1f1f1;
# }
# #T_39b8f_row1_col2, #T_39b8f_row6_col2, #T_39b8f_row31_col4 {
#   background-color: #292684;
#   color: #f1f1f1;
# }
# #T_39b8f_row1_col3, #T_39b8f_row30_col3 {
#   background-color: #f5f5cb;
#   color: #000000;
# }
# #T_39b8f_row1_col4, #T_39b8f_row7_col2 {
#   background-color: #38269e;
#   color: #f1f1f1;
# }
# #T_39b8f_row2_col0, #T_39b8f_row13_col4 {
#   background-color: #dd3c44;
#   color: #f1f1f1;
# }
# #T_39b8f_row2_col1, #T_39b8f_row2_col4 {
# ...

# %%
# top 10 active cases states
top10ActiveCases=covid_df.groupby(by='State/UnionTerritory').max()[['Active_cases','Date']].sort_values(by=['Active_cases'],ascending=False).reset_index()

# %%
print(top10ActiveCases)
# Out:
#                         State/UnionTerritory  Active_cases       Date
# 0                                Maharashtra        701614 2021-08-11
# 1                                  Karnataka        605515 2021-08-11
# 2                                     Kerala        445692 2021-08-11
# 3                                 Tamil Nadu        313048 2021-08-11
# 4                              Uttar Pradesh        310783 2021-08-11
# 5                                  Rajasthan        212753 2021-08-11
# 6                             Andhra Pradesh        211554 2021-08-11
# 7                                    Gujarat        148297 2021-08-11
# 8                                West Bengal        132181 2021-08-11
# 9                               Chhattisgarh        131245 2021-08-11
# 10                                   Haryana        116867 2021-08-11
# 11                                     Bihar        115152 2021-08-11
# ...

# %%
fig=plt.figure(figsize=(16,10))
plt.title("Top 10 states with most Active Cases  in India",size=22)
ax=sns.barplot(data=top10ActiveCases.iloc[:10],y='Active_cases',x='State/UnionTerritory', linewidth=2,edgecolor='black')
plt.xlabel("State/UnionTerritory")
plt.ylabel("Total Active Cases")
plt.show()

# %%
# top states with highest number of deaths
top10Deaths=covid_df.groupby(by='State/UnionTerritory').max()[['Deaths','Date']].sort_values(by=['Deaths'],ascending=False).reset_index()

# %%
fig=plt.figure(figsize=(16,10))
plt.title("Top 10 states with most Deaths in India",size=22)
ax=sns.barplot(data=top10Deaths.iloc[:10],y='Deaths',x='State/UnionTerritory',linewidth=2,edgecolor='black')
plt.xlabel("States")
plt.ylabel("Total Deaths")
plt.show()

# %%
#Growth Trend
fig=plt.figure(figsize=(12,6))
ax=sns.lineplot(data=covid_df[covid_df['State/UnionTerritory'].isin(['Maharashtra','Karnataka','Kerala','Tamil Nadu','Uttar Pradesh'])],x='Date',y='Active_cases',hue='State/UnionTerritory')
#ax.set_title("Top 5 Affected States in India",size=16)

# %%
vaccine_df.rename(columns={'Updated On':'Vaccine_Date'},inplace=True)

# %%
vaccine_df.head()
# Out:
#   Vaccine_Date  State  Total Doses Administered  Sessions    Sites  \
# 0   16/01/2021  India                   48276.0    3455.0   2957.0
# 1   17/01/2021  India                   58604.0    8532.0   4954.0
# 2   18/01/2021  India                   99449.0   13611.0   6583.0
# 3   19/01/2021  India                  195525.0   17855.0   7951.0
# 4   20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %%
vaccine_df.isnull().sum()
# Out:
# Vaccine_Date                              0
# State                                     0
# Total Doses Administered                224
# Sessions                                224
#  Sites                                  224
# First Dose Administered                 224
# Second Dose Administered                224
# Male (Doses Administered)               384
# Female (Doses Administered)             384
# Transgender (Doses Administered)        384
#  Covaxin (Doses Administered)           224
# CoviShield (Doses Administered)         224
# Sputnik V (Doses Administered)         4850
# AEFI                                   2407
# 18-44 Years (Doses Administered)       6143
# 45-60 Years (Doses Administered)       6143
# 60+ Years (Doses Administered)         6143
# 18-44 Years(Individuals Vaccinated)    4112
# 45-60 Years(Individuals Vaccinated)    4111
# 60+ Years(Individuals Vaccinated)      4111
# Male(Individuals Vaccinated)           7685
# ...

# %%
vaccination=vaccine_df.drop(columns=['Sputnik V (Doses Administered)','AEFI','18-44 Years (Doses Administered)','45-60 Years (Doses Administered)','60+ Years (Doses Administered)'],axis=1)
vaccination.head()
# Out:
#   Vaccine_Date  State  Total Doses Administered  Sessions    Sites  \
# 0   16/01/2021  India                   48276.0    3455.0   2957.0
# 1   17/01/2021  India                   58604.0    8532.0   4954.0
# 2   18/01/2021  India                   99449.0   13611.0   6583.0
# 3   19/01/2021  India                  195525.0   17855.0   7951.0
# 4   20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %%
#Male vs Female Vaccination

import matplotlib.pyplot as plt

# Summing up the vaccination counts
male = vaccination['Male(Individuals Vaccinated)'].sum()
female = vaccination['Female(Individuals Vaccinated)'].sum()

# Data for the pie chart
sizes = [male, female]
labels = ["Male", "Female"]

# Creating the pie chart
plt.figure(figsize=(8, 6))  # Optional: Set the figure size
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title("Male vs Female Vaccination")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.legend(title="Two Genders:", bbox_to_anchor=(1.05, 1), loc='upper left')
# Showing the pie chart
plt.show()

# %%
vaccine=vaccine_df[vaccine_df.State!='India']
vaccine.head()
# Out:
#     Vaccine_Date                        State  Total Doses Administered  \
# 212   16/01/2021  Andaman and Nicobar Islands                      23.0
# 213   17/01/2021  Andaman and Nicobar Islands                      23.0
# 214   18/01/2021  Andaman and Nicobar Islands                      42.0
# 215   19/01/2021  Andaman and Nicobar Islands                      89.0
# 216   20/01/2021  Andaman and Nicobar Islands                     124.0
#
#      Sessions  Sites  First Dose Administered  Second Dose Administered  \
# 212       2.0    2.0                     23.0                       0.0
# 213       2.0    2.0                     23.0                       0.0
# 214       9.0    2.0                     42.0                       0.0
# 215      12.0    2.0                     89.0                       0.0
# 216      16.0    3.0                    124.0                       0.0
#
#      Male (Doses Administered)  Female (Doses Administered)  \
# ...

# %%
vaccine_data =vaccine.rename(columns={'Total Individuals Vaccinated':'Total'},inplace=True)
vaccine.head()
# Out:
# C:\Users\rmnjs\AppData\Local\Temp\ipykernel_9264\2212435228.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vaccine_data =vaccine.rename(columns={'Total Individuals Vaccinated':'Total'},inplace=True)
#     Vaccine_Date                        State  Total Doses Administered  \
# 212   16/01/2021  Andaman and Nicobar Islands                      23.0
# 213   17/01/2021  Andaman and Nicobar Islands                      23.0
# 214   18/01/2021  Andaman and Nicobar Islands                      42.0
# 215   19/01/2021  Andaman and Nicobar Islands                      89.0
# 216   20/01/2021  Andaman and Nicobar Islands                     124.0
#
#      Sessions  Sites  First Dose Administered  Second Dose Administered  \
# 212       2.0    2.0                     23.0                       0.0
# ...

# %%
# max_vacc = vaccine.groupby('State')['Total'].sum().nlargest(5)

# %%
#Most vaccinated State
max_vacc1=vaccine.groupby('State')['Total'].sum().to_frame('Total')
max_vacc=max_vacc1.sort_values(by='Total',ascending=False)[:5]

# %%
fig=plt.figure(figsize=(12,5))
plt.title("Top 5 Vaccinated States in India",size=16)
x=sns.barplot(data=max_vacc.iloc[:10],y=max_vacc.Total,x=max_vacc.index,linewidth=2,edgecolor='black')

# %%
#Least vaccinated State
min_vacc1=vaccine.groupby('State')['Total'].sum().to_frame('Total')
min_vacc=min_vacc1.sort_values(by='Total',ascending=True)[:5]

# %%
fig=plt.figure(figsize=(12,5))
plt.title("Least 5 Vaccinated States in India",size=16)
x=sns.barplot(data=max_vacc.iloc[:10],y=min_vacc.Total,x=min_vacc.index,linewidth=2,edgecolor='black')

# %% [markdown]
# To create a figure with two rows and three columns, incorporating the various plots you've provided, you can use the matplotlib.pyplot.subplots function to set up the grid and then plot each of your figures in the appropriate subplot. Here's how you can organize and plot all the figures into a single figure with a 2x3 grid:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a 2x3 grid for subplots
fig, axes = plt.subplots(2, 3, figsize=(30, 20))


# Plot 0: Top 10 states with most Active Cases in India
sns.barplot(data=top10ActiveCases.iloc[:10], y='Active_cases', x='State/UnionTerritory', linewidth=2,color='blue', edgecolor='black', ax=axes[0, 0])
axes[0, 0].set_title("Top 10 states with most Active Cases in India", size=22)
axes[0, 0].set_xlabel("State/UnionTerritory")
axes[0, 0].set_ylabel("Total Active Cases")
axes[0, 0].tick_params(axis='x', rotation=45)

# Plot 1: Top 10 states with most Deaths in India
sns.barplot(data=top10Deaths.iloc[:10], y='Deaths', x='State/UnionTerritory', linewidth=2, edgecolor='black', ax=axes[0, 1])
axes[0, 1].set_title("Top 10 states with most Deaths in India", size=22)
axes[0, 1].set_xlabel("States")
axes[0, 1].set_ylabel("Total Deaths")

# Plot 2: Growth Trend
sns.lineplot(data=covid_df[covid_df['State/UnionTerritory'].isin(['Maharashtra','Karnataka','Kerala','Tamil Nadu','Uttar Pradesh'])], x='Date', y='Active_cases', hue='State/UnionTerritory', ax=axes[0, 2])
axes[0, 2].set_title("Growth Trend in Selected States", size=22)
axes[0, 2].set_xlabel("Date")
axes[0, 2].set_ylabel("Active Cases")

# Plot 3: Pie chart for Male vs Female Vaccination
sizes = [male, female]
labels = ["Male", "Female"]
axes[1, 0].pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
axes[1, 0].set_title("Male vs Female Vaccination", size=16)
axes[1, 0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Plot 4: Top 5 Vaccinated States in India
sns.barplot(data=max_vacc.iloc[:5], y='Total', x=max_vacc.index[:5], linewidth=2, edgecolor='black', ax=axes[1, 1])
axes[1, 1].set_title("Top 5 Vaccinated States in India", size=16)
axes[1, 1].set_xlabel("States")
axes[1, 1].set_ylabel("Total Vaccinations")

# Plot 5: Least 5 Vaccinated States in India
sns.barplot(data=min_vacc.iloc[:5], y='Total', x=min_vacc.index[:5], linewidth=2, edgecolor='black', ax=axes[1, 2])
axes[1, 2].set_title("Least 5 Vaccinated States in India", size=16)
axes[1, 2].set_xlabel("States")
axes[1, 2].set_ylabel("Total Vaccinations")

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Explanation:
# - `plt.subplots(2, 3, figsize=(18, 12))`: Creates a figure with a grid of 2 rows and 3 columns.
# - `ax=axes[i, j]`: Specifies the subplot location for each plot.
# - `plt.tight_layout()`: Adjusts subplot parameters to give specified padding and prevent overlap.

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Example data (make sure to replace it with your actual data)
# states = ['State1', 'State2', 'State3', 'State4', 'State5', 'State6', 'State7', 'State8', 'State9', 'State10']
# active_cases = [100, 200, 150, 300, 250, 400, 350, 450, 500, 550]
# recovered_cases = [80, 150, 120, 250, 200, 350, 300, 400, 450, 500]

# # Create a 2x3 grid for subplots
# fig, axes = plt.subplots(2, 3, figsize=(30, 20))

# # Plot 0: Top 10 states with most Active Cases in India
# axes[0, 0].bar(states, active_cases, color='blue', edgecolor='black')
# axes[0, 0].set_title("Top 10 states with most Active Cases in India", size=22)
# axes[0, 0].set_xlabel("State/UnionTerritory")
# axes[0, 0].set_ylabel("Total Active Cases")
# axes[0, 0].tick_params(axis='x', rotation=45)

# # Plot 1: Top 10 states with most Recovered Cases in India
# axes[0, 1].bar(states, recovered_cases, color='green', edgecolor='black')
# axes[0, 1].set_title("Top 10 states with most Recovered Cases in India", size=22)
# axes[0, 1].set_xlabel("State/UnionTerritory")
# axes[0, 1].set_ylabel("Total Recovered Cases")
# axes[0, 1].tick_params(axis='x', rotation=90)

# # Example for remaining plots
# for i in range(2, 6):
#     row, col = divmod(i, 3)
#     # Example line plot (replace with your desired plot type and data)
#     axes[row, col].plot(states, active_cases, marker='o', linestyle='-', color='red')
#     axes[row, col].set_title(f"Plot {i}", size=22)
#     axes[row, col].set_xlabel("State/UnionTerritory")
#     axes[row, col].set_ylabel("Value")
#     axes[row, col].tick_params(axis='x', rotation=45)

# plt.tight_layout()
# plt.show()

# %%
# import seaborn as sns
# import pandas as pd

# # Example data
# data = {'State/UnionTerritory': ['State1', 'State2', 'State3'], 'Cases': [100, 200, 150]}
# df = pd.DataFrame(data)

# sns.barplot(data=df, x='State/UnionTerritory', y='Cases', palette='Blues', edgecolor='black')
# plt.title("State Cases", fontsize=14)
# plt.xlabel("State/UnionTerritory")
# plt.ylabel("Total Cases")
# plt.show()
# Out:
# C:\Users\rmnjs\AppData\Local\Temp\ipykernel_6012\1642670420.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='State/UnionTerritory', y='Cases', palette='Blues', edgecolor='black')

# %%
# import matplotlib.pyplot as plt

# # Example data
# states = ['State1', 'State2', 'State3']
# cases = [100, 200, 150]

# plt.bar(states, cases, color='blue', edgecolor='black')
# plt.title("State Cases", fontsize=14)
# plt.xlabel("State/UnionTerritory")
# plt.ylabel("Total Cases")
# plt.show()
